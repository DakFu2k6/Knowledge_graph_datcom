# %%
import pandas as pd

# %%
brop = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\broaderRelationsOccPillar_en.csv")
brsp = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\broaderRelationsSkillPillar_en.csv")
cs = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\conceptSchemes_en.csv")
dcsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\digCompSkillsCollection_en.csv")
dsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\digitalSkillsCollection_en.csv")
gsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\greenSkillsCollection_en.csv")
iscog = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\ISCOGroups_en.csv")
lsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\languageSkillsCollection_en.csv")
oe = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\occupations_en.csv")
osr = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\occupationSkillRelations_en.csv")
roc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\researchOccupationsCollection_en.csv")
rsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\researchSkillsCollection_en.csv")
sg = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\skillGroups_en.csv")
se = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\skills_en.csv")
sh = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\skillsHierarchy_en.csv")
ssr = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\skillSkillRelations_en.csv")
tsc = pd.read_csv(r"C:\Users\Admin\Downloads\SkillGraph\ESCO dataset - v1.2.0 - classification - en - csv\transversalSkillsCollection_en.csv")

# %%
print(brop.head())
print(brop.describe())
print(brop.columns)
# Out:
#   conceptType                             conceptUri broaderType  \
# 0   ISCOGroup    http://data.europa.eu/esco/isco/C01   ISCOGroup
# 1   ISCOGroup   http://data.europa.eu/esco/isco/C011   ISCOGroup
# 2   ISCOGroup  http://data.europa.eu/esco/isco/C0110   ISCOGroup
# 3   ISCOGroup    http://data.europa.eu/esco/isco/C02   ISCOGroup
# 4   ISCOGroup   http://data.europa.eu/esco/isco/C021   ISCOGroup
#
#                              broaderUri
# 0    http://data.europa.eu/esco/isco/C0
# 1   http://data.europa.eu/esco/isco/C01
# 2  http://data.europa.eu/esco/isco/C011
# 3    http://data.europa.eu/esco/isco/C0
# 4   http://data.europa.eu/esco/isco/C02
#        conceptType                                         conceptUri  \
# count         3652                                               3652
# unique           2                                               3648
# top     Occupation  http://data.europa.eu/esco/occupation/8d463763...
# ...

# %%
print(brsp.head())
print(brsp.describe())
print(brsp.columns)
# Out:
#   conceptType                               conceptUri broaderType  \
# 0  SkillGroup    http://data.europa.eu/esco/isced-f/00  SkillGroup
# 1  SkillGroup   http://data.europa.eu/esco/isced-f/000  SkillGroup
# 2  SkillGroup  http://data.europa.eu/esco/isced-f/0000  SkillGroup
# 3  SkillGroup   http://data.europa.eu/esco/isced-f/001  SkillGroup
# 4  SkillGroup  http://data.europa.eu/esco/isced-f/0011  SkillGroup
#
#                                           broaderUri
# 0  http://data.europa.eu/esco/skill/c46fcb45-5c14...
# 1              http://data.europa.eu/esco/isced-f/00
# 2             http://data.europa.eu/esco/isced-f/000
# 3              http://data.europa.eu/esco/isced-f/00
# 4             http://data.europa.eu/esco/isced-f/001
#                      conceptType  \
# count                      20822
# unique                         2
# top     KnowledgeSkillCompetence
# freq                       20186
#
# ...

# %%
print(cs.head())
print(cs.describe())
print(cs.columns)
# Out:
#      conceptType                                   conceptSchemeUri  \
# 0  ConceptScheme  http://data.europa.eu/esco/concept-scheme/6c93...
# 1  ConceptScheme  http://data.europa.eu/esco/concept-scheme/8ae4...
# 2  ConceptScheme  http://data.europa.eu/esco/concept-scheme/digcomp
# 3  ConceptScheme    http://data.europa.eu/esco/concept-scheme/green
# 4  ConceptScheme  http://data.europa.eu/esco/concept-scheme/isced-f
#
#                                       preferredLabel title    status  \
# 0                                            Digital   NaN  released
# 1                               Research occupations   NaN  released
# 2                                            DigComp   NaN  released
# 3                                              Green   NaN  released
# 4  International standard classification of educa...   NaN  released
#
#   description                                      hasTopConcept
# 0         NaN  http://data.europa.eu/esco/skill/dad7e408-162f...
# ...

# %%
print(dcsc.head())
print(dcsc.describe())
print(dcsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/14832d87-2f2f...
# 1  http://data.europa.eu/esco/skill/16a00c69-9c74...
# 2  http://data.europa.eu/esco/skill/1a4cc54f-1e53...
# 3  http://data.europa.eu/esco/skill/1d6c7de4-350e...
# 4  http://data.europa.eu/esco/skill/21d2f96d-35f7...
#
#                                    preferredLabel    status         skillType  \
# 0                        solve technical problems  released  skill/competence
# 1                                  use e-services  released  skill/competence
# 2             creatively use digital technologies  released  skill/competence
# 3  evaluate data, information and digital content  released  skill/competence
# ...

# %%
print(dsc.head())
print(dsc.describe())
print(dsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/000f1d3d-220f...
# 1  http://data.europa.eu/esco/skill/00c04e40-35ea...
# 2  http://data.europa.eu/esco/skill/013441c1-1f13...
# 3  http://data.europa.eu/esco/skill/0189f448-179e...
# 4  http://data.europa.eu/esco/skill/01d269d9-b058...
#
#                                 preferredLabel    status         skillType  \
# 0                                      Haskell  released         knowledge
# 1                      incremental development  released         knowledge
# 2                                     KDevelop  released         knowledge
# 3         Absorb (learning management systems)  released         knowledge
# 4  develop blockchain innovative architectures  released  skill/competence
#
# ...

# %%
print(gsc.head())
print(gsc.describe())
print(gsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/001d46db-035e...
# 1  http://data.europa.eu/esco/skill/0037c821-2898...
# 2  http://data.europa.eu/esco/skill/0058526a-11e9...
# 3  http://data.europa.eu/esco/skill/00735755-adc6...
# 4  http://data.europa.eu/esco/skill/0082c13b-5866...
#
#                      preferredLabel    status         skillType  \
# 0  train staff to reduce food waste  released  skill/competence
# 1    develop energy saving concepts  released  skill/competence
# 2         conduct research on flora  released  skill/competence
# 3                 install heat pump  released  skill/competence
# 4      design biomass installations  released  skill/competence
#
#         reuseLevel                                          altLabels  \
# ...

# %%
print(iscog.head())
print(iscog.describe())
print(iscog.columns)
# Out:
#   conceptType                             conceptUri  code  \
# 0   ISCOGroup     http://data.europa.eu/esco/isco/C0     0
# 1   ISCOGroup    http://data.europa.eu/esco/isco/C01     1
# 2   ISCOGroup   http://data.europa.eu/esco/isco/C011    11
# 3   ISCOGroup  http://data.europa.eu/esco/isco/C0110   110
# 4   ISCOGroup    http://data.europa.eu/esco/isco/C02     2
#
#                            preferredLabel    status  altLabels  \
# 0                Armed forces occupations  released        NaN
# 1      Commissioned armed forces officers  released        NaN
# 2      Commissioned armed forces officers  released        NaN
# 3      Commissioned armed forces officers  released        NaN
# 4  Non-commissioned armed forces officers  released        NaN
#
#                                             inScheme  \
# 0  http://data.europa.eu/esco/concept-scheme/occu...
# 1  http://data.europa.eu/esco/concept-scheme/isco...
# 2  http://data.europa.eu/esco/concept-scheme/isco...
# ...

# %%
print(lsc.head())
print(lsc.describe())
print(lsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri         skillType  \
# 0  http://data.europa.eu/esco/skill/01f10952-cb59...  skill/competence
# 1  http://data.europa.eu/esco/skill/021c8a09-6b8d...         knowledge
# 2  http://data.europa.eu/esco/skill/02d68c2b-1722...  skill/competence
# 3  http://data.europa.eu/esco/skill/037b5e5f-db3c...  skill/competence
# 4  http://data.europa.eu/esco/skill/03a53283-d3ee...  skill/competence
#
#     reuseLevel                   preferredLabel    status  \
# 0  transversal                  write Hungarian  released
# 1  transversal  understand spoken Luxembourgish  released
# 2  transversal        understand written Korean  released
# 3  transversal      understand spoken Hungarian  released
# 4  transversal          understand spoken Welsh  released
#
# ...

# %%
print(oe.head())
print(oe.describe())
print(oe.columns)
# Out:
#   conceptType                                         conceptUri  iscoGroup  \
# 0  Occupation  http://data.europa.eu/esco/occupation/00030d09...       2654
# 1  Occupation  http://data.europa.eu/esco/occupation/000e93a3...       8121
# 2  Occupation  http://data.europa.eu/esco/occupation/0019b951...       7543
# 3  Occupation  http://data.europa.eu/esco/occupation/0022f466...       3155
# 4  Occupation  http://data.europa.eu/esco/occupation/002da35b...       2431
#
#                    preferredLabel  \
# 0              technical director
# 1  metal drawing machine operator
# 2      precision device inspector
# 3   air traffic safety technician
# 4     hospitality revenue manager
#
#                                            altLabels hiddenLabels    status  \
# 0  technical and operations director\nhead of tec...          NaN  released
# 1  metal drawing machine technician\nmetal drawin...          NaN  released
# ...

# %%
print(osr.head())
print(osr.describe())
print(osr.columns)
# Out:
#                                        occupationUri relationType  \
# 0  http://data.europa.eu/esco/occupation/00030d09...    essential
# 1  http://data.europa.eu/esco/occupation/00030d09...    essential
# 2  http://data.europa.eu/esco/occupation/00030d09...    essential
# 3  http://data.europa.eu/esco/occupation/00030d09...    essential
# 4  http://data.europa.eu/esco/occupation/00030d09...    essential
#
#           skillType                                           skillUri
# 0         knowledge  http://data.europa.eu/esco/skill/fed5b267-73fa...
# 1  skill/competence  http://data.europa.eu/esco/skill/05bc7677-5a64...
# 2  skill/competence  http://data.europa.eu/esco/skill/271a36a0-bc7a...
# 3  skill/competence  http://data.europa.eu/esco/skill/47ed1d37-971b...
# 4  skill/competence  http://data.europa.eu/esco/skill/591dd514-735b...
#                                             occupationUri relationType  \
# count                                              129004       129004
# ...

# %%
print(roc.head())
print(roc.describe())
print(roc.columns)
# Out:
#   conceptType                                         conceptUri  \
# 0  Occupation  http://data.europa.eu/esco/occupation/01ffb917...
# 1  Occupation  http://data.europa.eu/esco/occupation/0611f232...
# 2  Occupation  http://data.europa.eu/esco/occupation/0959cd1d...
# 3  Occupation  http://data.europa.eu/esco/occupation/0bf5d25a...
# 4  Occupation  http://data.europa.eu/esco/occupation/0c7c9606...
#
#             preferredLabel    status  \
# 0      biomedical engineer  released
# 1            criminologist  released
# 2       economics lecturer  released
# 3        medicine lecturer  released
# 4  medical device engineer  released
#
#                                            altLabels  \
# 0  BME consultant | bio-medical engineer | biomed...
# 1  criminology science researcher | criminology s...
# 2  economics teacher | university economics lectu...
# 3  clinical lecturer | university lecturer in med...
# 4  engineer in biomedical systems | engineer of m...
#
# ...

# %%
print(rsc.head())
print(rsc.describe())
print(rsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri  \
# 0  http://data.europa.eu/esco/skill/00b9a3aa-7070...
# 1  http://data.europa.eu/esco/skill/08b04e53-ed25...
# 2  http://data.europa.eu/esco/skill/20a8fe89-d4eb...
# 3  http://data.europa.eu/esco/skill/2b1e2927-3542...
# 4  http://data.europa.eu/esco/skill/2b34764d-637c...
#
#                                       preferredLabel    status  \
# 0  draft scientific or academic papers and techni...  released
# 1                               manage research data  released
# 2  interact professionally in research and profes...  released
# 3    disseminate results to the scientific community  released
# 4                       operate open source software  released
#
#           skillType       reuseLevel  \
# 0  skill/competence     cross-sector
# ...

# %%
print(sg.head())
print(sg.describe())
print(sg.columns)
# Out:
#   conceptType                               conceptUri  \
# 0  SkillGroup    http://data.europa.eu/esco/isced-f/00
# 1  SkillGroup   http://data.europa.eu/esco/isced-f/000
# 2  SkillGroup  http://data.europa.eu/esco/isced-f/0000
# 3  SkillGroup   http://data.europa.eu/esco/isced-f/001
# 4  SkillGroup  http://data.europa.eu/esco/isced-f/0011
#
#                                       preferredLabel altLabels hiddenLabels  \
# 0              generic programmes and qualifications       NaN          NaN
# 1  generic programmes and qualifications not furt...       NaN          NaN
# 2  generic programmes and qualifications not furt...       NaN          NaN
# 3                basic programmes and qualifications       NaN          NaN
# 4                basic programmes and qualifications       NaN          NaN
#
#      status              modifiedDate scopeNote  \
# 0  released                       NaN       NaN
# 1  released  2023-07-13T15:16:44.968Z       NaN
# ...

# %%
print(se.head())
print(se.describe())
print(se.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri         skillType  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...  skill/competence
# 1  http://data.europa.eu/esco/skill/00064735-8fad...  skill/competence
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...  skill/competence
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...  skill/competence
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...  skill/competence
#
#             reuseLevel                                     preferredLabel  \
# 0      sector-specific                               manage musical staff
# 1  occupation-specific                  supervise correctional procedures
# 2      sector-specific                    apply anti-oppressive practices
# ...

# %%
print(sh.head())
print(sh.describe())
print(sh.columns)
# Out:
#                                          Level 0 URI  \
# 0  http://data.europa.eu/esco/skill/e35a5936-091d...
# 1  http://data.europa.eu/esco/skill/e35a5936-091d...
# 2  http://data.europa.eu/esco/skill/e35a5936-091d...
# 3  http://data.europa.eu/esco/skill/335228d2-297d...
# 4  http://data.europa.eu/esco/skill/335228d2-297d...
#
#           Level 0 preferred term  \
# 0  language skills and knowledge
# 1  language skills and knowledge
# 2  language skills and knowledge
# 3                         skills
# 4                         skills
#
#                                          Level 1 URI Level 1 preferred term  \
# 0                                                NaN                    NaN
# 1  http://data.europa.eu/esco/skill/43f425aa-f45d...              languages
# 2  http://data.europa.eu/esco/skill/e434e71a-f068...    classical languages
# 3                                                NaN                    NaN
# ...

# %%
print(ssr.head())
print(ssr.describe())
print(ssr.columns)
# Out:
#                                     originalSkillUri originalSkillType  \
# 0  http://data.europa.eu/esco/skill/00064735-8fad...         knowledge
# 1  http://data.europa.eu/esco/skill/000bb1e4-89f0...         knowledge
# 2  http://data.europa.eu/esco/skill/0023e7a5-43da...         knowledge
# 3  http://data.europa.eu/esco/skill/00298d97-3dc3...         knowledge
# 4  http://data.europa.eu/esco/skill/008a0e0d-7380...         knowledge
#
#   relationType relatedSkillType  \
# 0     optional        knowledge
# 1     optional        knowledge
# 2     optional        knowledge
# 3     optional        knowledge
# 4     optional        knowledge
#
#                                      relatedSkillUri
# 0  http://data.europa.eu/esco/skill/d4a0744a-508b...
# 1  http://data.europa.eu/esco/skill/b70ab677-5781...
# 2  http://data.europa.eu/esco/skill/5753e2ca-8934...
# 3  http://data.europa.eu/esco/skill/1ff53c92-370d...
# 4  http://data.europa.eu/esco/skill/af0bbc31-b54d...
# ...

# %%
print(tsc.head())
print(tsc.describe())
print(tsc.columns)
# Out:
#                 conceptType  \
# 0  KnowledgeSkillCompetence
# 1  KnowledgeSkillCompetence
# 2  KnowledgeSkillCompetence
# 3  KnowledgeSkillCompetence
# 4  KnowledgeSkillCompetence
#
#                                           conceptUri         skillType  \
# 0  http://data.europa.eu/esco/skill/001115fb-569f...  skill/competence
# 1  http://data.europa.eu/esco/skill/0171653e-c8e9...  skill/competence
# 2  http://data.europa.eu/esco/skill/045f71e6-0699...  skill/competence
# 3  http://data.europa.eu/esco/skill/05aa7c09-46e7...  skill/competence
# 4  http://data.europa.eu/esco/skill/0b709c64-a57a...  skill/competence
#
#     reuseLevel                                     preferredLabel    status  \
# 0  transversal                                    show initiative  released
# 1  transversal  adopt ways to foster biodiversity and animal w...  released
# 2  transversal                                      advise others  released
# ...

# %%
ajp = pd.read_csv("all_job_post.csv")
eks = pd.read_csv("extracted_kg_skills.csv")

# %%
print(ajp.head())
print(ajp.describe())
print(ajp.columns)
# Out:
#        job_id category                                 job_title  \
# 0  3902668440       HR              Sr Human Resource Generalist
# 1  3905823748       HR                   Human Resources Manager
# 2  3905854799       HR               Director of Human Resources
# 3  3905834061       HR             Chief Human Resources Officer
# 4  3906250451       HR  Human Resources Generalist (Hybrid Role)
#
#                                      job_description  \
# 0  SUMMARY\nTHE SR. HR GENERALIST PROVIDES HR EXP...
# 1  BE PART OF A STELLAR TEAM AT YSB AS THE MANAGE...
# 2  OUR CLIENT IS A THRIVING ORGANIZATION OFFERING...
# 3  JOB TITLE: CHIEF HUMAN RESOURCES OFFICER (CHRO...
# 4  DESCRIPTION\n\n WHO WE ARE \n\nAVI-SPL IS A DI...
#
#                                        job_skill_set
# 0  ['employee relations', 'talent acquisition', '...
# 1  ['Talent Acquisition', 'Employee Performance M...
# 2  ['Human Resources Management', 'Recruitment', ...
# ...

# %%
print(eks.head())
print(eks.describe())
print(eks.columns)
# Out:
#        job_id category                                 job_title  \
# 0  3902668440       HR              Sr Human Resource Generalist
# 1  3905823748       HR                   Human Resources Manager
# 2  3905854799       HR               Director of Human Resources
# 3  3905834061       HR             Chief Human Resources Officer
# 4  3906250451       HR  Human Resources Generalist (Hybrid Role)
#
#                                         ground_truth  \
# 0  ['employee relations', 'talent acquisition', '...
# 1  ['talent acquisition', 'employee performance m...
# 2  ['human resources management', 'recruitment', ...
# 3  ['talent management', 'organizational developm...
# 4  ['microsoft office', 'data analysis', 'employe...
#
#                                       extracted_flat  \
# 0  ['dayforce', 'employee relations', 'talent acq...
# 1  ['employee performance tools', 'microsoft offi...
# 2  ['employee relations', 'random drug testing pr...
# ...
